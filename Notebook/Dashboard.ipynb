# %%
pip install dash dash-bootstrap-components jupyter-dash
# Out:
# Requirement already satisfied: dash in c:\users\neo dev 1\anaconda\lib\site-packages (2.18.2)
# Requirement already satisfied: dash-bootstrap-components in c:\users\neo dev 1\anaconda\lib\site-packages (1.6.0)
# Requirement already satisfied: jupyter-dash in c:\users\neo dev 1\anaconda\lib\site-packages (0.4.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: plotly>=5.0.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (5.24.1)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (75.1.0)
# Requirement already satisfied: ipython in c:\users\neo dev 1\anaconda\lib\site-packages (from jupyter-dash) (8.27.0)
# Requirement already satisfied: ipykernel in c:\users\neo dev 1\anaconda\lib\site-packages (from jupyter-dash) (6.28.0)
# Requirement already satisfied: ansi2html in c:\users\neo dev 1\anaconda\lib\site-packages (from jupyter-dash) (1.9.2)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\neo dev 1\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\neo dev 1\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\neo dev 1\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\neo dev 1\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (1.6.2)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from plotly>=5.0.0->dash) (8.2.3)
# Requirement already satisfied: packaging in c:\users\neo dev 1\anaconda\lib\site-packages (from plotly>=5.0.0->dash) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\neo dev 1\anaconda\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: comm>=0.1.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (1.6.7)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (5.7.2)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (0.1.6)
# Requirement already satisfied: psutil in c:\users\neo dev 1\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (5.9.0)
# Requirement already satisfied: pyzmq>=24 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (25.1.2)
# Requirement already satisfied: tornado>=6.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (6.4.1)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipykernel->jupyter-dash) (5.14.3)
# Requirement already satisfied: decorator in c:\users\neo dev 1\anaconda\lib\site-packages (from ipython->jupyter-dash) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipython->jupyter-dash) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipython->jupyter-dash) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from ipython->jupyter-dash) (2.15.1)
# Requirement already satisfied: stack-data in c:\users\neo dev 1\anaconda\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: colorama in c:\users\neo dev 1\anaconda\lib\site-packages (from ipython->jupyter-dash) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\neo dev 1\anaconda\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\neo dev 1\anaconda\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from requests->dash) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\neo dev 1\anaconda\lib\site-packages (from requests->dash) (2024.8.30)
# Requirement already satisfied: six>=1.7.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from retrying->dash) (1.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\neo dev 1\anaconda\lib\site-packages (from jedi>=0.16->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\neo dev 1\anaconda\lib\site-packages (from jupyter-client>=6.1.12->ipykernel->jupyter-dash) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\neo dev 1\anaconda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (3.10.0)
# Requirement already satisfied: pywin32>=300 in c:\users\neo dev 1\anaconda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter-dash) (305.1)
# Requirement already satisfied: wcwidth in c:\users\neo dev 1\anaconda\lib\site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: executing in c:\users\neo dev 1\anaconda\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.8.3)
# Requirement already satisfied: asttokens in c:\users\neo dev 1\anaconda\lib\site-packages (from stack-data->ipython->jupyter-dash) (2.0.5)
# Requirement already satisfied: pure-eval in c:\users\neo dev 1\anaconda\lib\site-packages (from stack-data->ipython->jupyter-dash) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dash pandas plotly dash-bootstrap-components
# Out:
# Requirement already satisfied: dash in c:\users\neo dev 1\anaconda\lib\site-packages (2.18.2)
# Requirement already satisfied: pandas in c:\users\neo dev 1\anaconda\lib\site-packages (2.2.2)
# Requirement already satisfied: plotly in c:\users\neo dev 1\anaconda\lib\site-packages (5.24.1)
# Requirement already satisfied: dash-bootstrap-components in c:\users\neo dev 1\anaconda\lib\site-packages (1.6.0)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (3.0.3)
# Requirement already satisfied: dash-html-components==2.0.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (5.0.0)
# Requirement already satisfied: importlib-metadata in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (7.0.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (4.11.0)
# Requirement already satisfied: requests in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (2.32.3)
# Requirement already satisfied: retrying in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (1.3.4)
# Requirement already satisfied: nest-asyncio in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (1.6.0)
# Requirement already satisfied: setuptools in c:\users\neo dev 1\anaconda\lib\site-packages (from dash) (75.1.0)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\neo dev 1\anaconda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\neo dev 1\anaconda\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\neo dev 1\anaconda\lib\site-packages (from plotly) (8.2.3)
# Requirement already satisfied: packaging in c:\users\neo dev 1\anaconda\lib\site-packages (from plotly) (24.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\neo dev 1\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\neo dev 1\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\neo dev 1\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\neo dev 1\anaconda\lib\site-packages (from Flask<3.1,>=1.0.4->dash) (1.6.2)
# Requirement already satisfied: six>=1.5 in c:\users\neo dev 1\anaconda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from Werkzeug<3.1->dash) (2.1.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\neo dev 1\anaconda\lib\site-packages (from importlib-metadata->dash) (3.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\neo dev 1\anaconda\lib\site-packages (from requests->dash) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\neo dev 1\anaconda\lib\site-packages (from requests->dash) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\neo dev 1\anaconda\lib\site-packages (from requests->dash) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\neo dev 1\anaconda\lib\site-packages (from requests->dash) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\neo dev 1\anaconda\lib\site-packages (from click>=8.1.3->Flask<3.1,>=1.0.4->dash) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
pd.read_csv("Payal_Ramani.csv")

#pd.read_csv("Divyesh_Patel.csv")
# Out:
#             Name         Day Punch-in Punch-out Timer Hours Manual Hours  \
# 0   Payal Ramani  Sun 01-Jan    --:--     --:--       00:00        00:00
# 1   Payal Ramani  Mon 02-Jan    09:15     17:45       08:30        00:00
# 2   Payal Ramani  Tue 03-Jan    08:50     18:00       08:10        00:00
# 3   Payal Ramani  Wed 04-Jan    09:05     18:15       08:10        00:00
# 4   Payal Ramani  Thu 05-Jan    09:00     18:05       08:05        00:00
# 5   Payal Ramani  Fri 06-Jan    09:10     18:30       08:20        00:00
# 6   Payal Ramani  Sat 07-Jan    --:--     --:--       00:00        00:00
# 7   Payal Ramani  Sun 08-Jan    --:--     --:--       00:00        00:00
# 8   Payal Ramani  Mon 09-Jan    09:20     17:40       08:20        00:00
# 9   Payal Ramani  Tue 10-Jan    08:55     18:10       08:15        00:00
# 10  Payal Ramani  Wed 11-Jan    09:10     18:25       08:15        00:00
# 11  Payal Ramani  Thu 12-Jan    09:05     18:00       08:05        00:00
# 12  Payal Ramani  Fri 13-Jan    09:10     18:20       08:10        00:00
# 13  Payal Ramani  Sat 14-Jan    --:--     --:--       00:00        00:00
# 14  Payal Ramani  Sun 15-Jan    --:--     --:--       00:00        00:00
# 15  Payal Ramani  Mon 16-Jan    09:00     17:55       08:05        00:00
# 16  Payal Ramani  Tue 17-Jan    09:10     18:00       08:10        00:00
# 17  Payal Ramani  Wed 18-Jan    09:00     18:00       09:00        00:00
# 18  Payal Ramani  Thu 19-Jan    09:15     18:10       08:55        00:00
# 19  Payal Ramani  Fri 20-Jan    09:10     18:05       08:55        00:00
# 20  Payal Ramani  Sat 21-Jan    --:--     --:--       00:00        00:00
# 21  Payal Ramani  Sun 22-Jan    --:--     --:--       00:00        00:00
# 22  Payal Ramani  Mon 23-Jan    09:00     17:50       08:50        00:00
# 23  Payal Ramani  Tue 24-Jan    09:05     18:00       08:55        00:00
# 24  Payal Ramani  Wed 25-Jan    09:00     17:50       08:50        00:00
# 25  Payal Ramani  Thu 26-Jan    09:10     18:00       08:50        00:00
# 26  Payal Ramani  Fri 27-Jan    09:20     18:30       09:10        00:00
# 27  Period Total         NaN      NaN       NaN   171:35:00        00:00
#
#    Total Ex Idle Hours Idle Hours Total Inc Idle Hours
# 0                00:00      00:00                00:00
# 1                08:30      00:00                08:30
# 2                08:10      00:00                08:10
# 3                08:10      00:00                08:10
# 4                08:05      00:00                08:05
# 5                08:20      00:00                08:20
# 6                00:00      00:00                00:00
# 7                00:00      00:00                00:00
# 8                08:20      00:00                08:20
# 9                08:15      00:00                08:15
# 10               08:15      00:00                08:15
# 11               08:05      00:00                08:05
# 12               08:10      00:00                08:10
# 13               00:00      00:00                00:00
# 14               00:00      00:00                00:00
# 15               08:05      00:00                08:05
# 16               08:10      00:00                08:10
# 17               09:00      00:00                09:00
# 18               08:55      00:00                08:55
# 19               08:55      00:00                08:55
# 20               00:00      00:00                00:00
# 21               00:00      00:00                00:00
# 22               08:50      00:00                08:50
# 23               08:55      00:00                08:55
# 24               08:50      00:00                08:50
# 25               08:50      00:00                08:50
# 26               09:10      00:00                09:10
# 27           171:35:00      00:00            171:35:00

# %%
df.columns
# Out:
# Index(['Name', 'Day', 'Punch-in', 'Punch-out', 'Timer Hours', 'Manual Hours',
#        'Total Ex Idle Hours', 'Idle Hours', 'Total Inc Idle Hours',
#        'Worked Hours', 'Manual Total Hours', 'Late Punch', 'Overtime',
#        'Early Leave', 'Half Day', 'Leaves'],
#       dtype='object')

# %%
import pandas as pd
import plotly.express as px
from dash import dcc, html
import dash_bootstrap_components as dbc
import dash
from datetime import datetime

# Read the data
data = pd.read_csv("Divyesh_Patel.csv")

# Create DataFrame
df = pd.DataFrame(data)

# Function to convert time in HH:MM format to timedelta or return None if not available
def convert_time(t):
    try:
        return datetime.strptime(t, '%H:%M')
    except:
        return None

# Convert Punch-in and Punch-out to datetime if available
df['Punch-in'] = df['Punch-in'].apply(convert_time)
df['Punch-out'] = df['Punch-out'].apply(convert_time)

# Function to calculate worked hours
def calculate_worked_hours(row):
    if row['Punch-in'] and row['Punch-out']:
        return (row['Punch-out'] - row['Punch-in']).seconds / 3600
    return 0

# Calculate Worked Hours based on Punch-in and Punch-out times
df['Worked Hours'] = df.apply(calculate_worked_hours, axis=1)

# Calculate Manual Total Hours and Idle Hours as well
df['Manual Total Hours'] = pd.to_timedelta(df['Timer Hours'], errors='coerce').dt.total_seconds() / 3600
df['Idle Hours'] = pd.to_timedelta(df['Idle Hours'], errors='coerce').dt.total_seconds() / 3600
df['Total Ex Idle Hours'] = pd.to_timedelta(df['Total Ex Idle Hours'], errors='coerce').dt.total_seconds() / 3600
df['Total Inc Idle Hours'] = pd.to_timedelta(df['Total Inc Idle Hours'], errors='coerce').dt.total_seconds() / 3600

# Handle calculation of various metrics
df['Late Punch'] = df['Punch-in'].apply(lambda x: 1 if x and x.hour > 10 else 0)
df['Overtime'] = df['Worked Hours'].apply(lambda x: 1 if x > 8.5 else 0)
df['Early Leave'] = df['Punch-out'].apply(lambda x: 1 if x and x.hour < 20 else 0)
df['Half Day'] = df['Worked Hours'].apply(lambda x: 1 if x < 4.5 else 0)
df['Leaves'] = df['Worked Hours'].apply(lambda x: 1 if x == 0 else 0)

# Modify the 'Day' column to show the first letter of the day and the month abbreviation
def format_day(day):
    # Check if the day value is not "Total" or other unexpected formats
    if 'Total' in day:
        return day  # You can return the day as is or return a default value like 'Invalid'
    
    # Proceed with formatting if the day is in a valid format
    try:
        day_parts = day.split()
        day_name = day_parts[0][0]  # Get the first letter of the day name
        day_number = int(day_parts[1].split('-')[0])  # Get the numeric part of the day
        month = day_parts[1].split('-')[1][0]  # Get the first letter of the month
        return f"{day_name} {day_number}-{month}"
    except Exception as e:
        return f"Error: {str(e)}"  # Return an error message if the format is incorrect


df['Day'] = df['Day'].apply(format_day)

# Create the Dash app (no longer using JupyterDash)
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])

# Create the graphs and update the figures
# Overtime pie chart
overtime_fig = px.pie(df, names='Overtime', 
                      title="Overtime Days", 
                      color_discrete_map={0: 'lightgray', 1: 'pink'}, 
                      labels={0: 'Leave', 1: 'Worked'},
                      hole=0.3,  
                      template='plotly_dark',  
                      color_discrete_sequence=['#D3D3D3', '#FF69B4'])  
overtime_fig.update_traces(textinfo='percent+label')

# Late Punch pie chart
late_punch_fig = px.pie(df, names='Late Punch', 
                        title="Late Punch Days", 
                        color_discrete_map={0: 'blue', 1: 'orange'}, 
                        labels={0: 'Regular Day', 1: 'Late Punch Day'},
                        hole=0.3,  
                        template='plotly_dark',  
                        color_discrete_sequence=['#1F77B4', '#FF7F0E'])
late_punch_fig.update_traces(textinfo='percent+label')

# Half Day pie chart
half_day_fig = px.pie(df, names='Half Day', 
                      title="Half Days", 
                      color_discrete_map={0: 'purple', 1: 'pink'},
                      hole=0.3,  
                      labels={0: 'Full Day', 1: 'Half Day'},
                      color_discrete_sequence=['#800080', '#FF69B4'])  
half_day_fig.update_traces(textinfo='percent+label')

# Leaves pie chart
leaves_fig = px.pie(df, names='Leaves', 
                    title="Leave Days", 
                    color_discrete_map={0: 'pink', 1: 'gray'},
                    hole=0.3,  
                    labels={0: 'No Leave', 1: 'Leave'},
                    color_discrete_sequence=['#FF69B4', '#A9A9A9'])
leaves_fig.update_traces(textinfo='percent+label')

# App Layout
app.layout = html.Div([
    dbc.Row([  # Row for Title
        dbc.Col(html.H1("Attendance and Work Hours Dashboard", style={'textAlign': 'center', 'color': 'darkblue'}), width=12)
    ]),
    dbc.Row([  # Row for Bar Graph (Total Worked Hours Per Day)
        dbc.Col(dcc.Graph(
            id='work-hours-graph',
            figure=px.bar(df, x='Day', y='Worked Hours', 
                          color='Worked Hours', 
                          color_continuous_scale='Viridis', 
                          title="Total Worked Hours Per Day",
                          labels={'Worked Hours': 'Worked Hours (in Hours)', 'Day': 'Work Day'})
        ), width=12)
    ]),
    dbc.Row([  # Row for Pie Charts
        dbc.Col(dcc.Graph(
            id='overtime-graph',
            figure=overtime_fig
        ), width=6),

        dbc.Col(dcc.Graph(
            id='late-punch-graph',
            figure=late_punch_fig
        ), width=6)
    ]),
    dbc.Row([  # Row for Half Day and Leave Pie Charts
        dbc.Col(dcc.Graph(
            id='half-day-graph',
            figure=half_day_fig
        ), width=6),

        dbc.Col(dcc.Graph(
            id='leaves-graph',
            figure=leaves_fig
        ), width=6)
    ]),
    dbc.Row([  # Row for Worked Hours Trend Line Graph
        dbc.Col(dcc.Graph(
            id='worked-hours-trend',
            figure=px.line(df, x='Day', y='Worked Hours', 
                           title="Worked Hours Trend",
                           line_shape='linear', markers=True)
        ), width=12)
    ])
])

# Run the server on a different port
app.run_server(debug=True, port=8059)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8059/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
