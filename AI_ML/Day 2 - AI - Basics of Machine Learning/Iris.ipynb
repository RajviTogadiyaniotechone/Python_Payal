# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
df.head()
# Out:
#    sepal.length  sepal.width  petal.length  petal.width variety
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  Setosa
# 2           4.7          3.2           1.3          0.2  Setosa
# 3           4.6          3.1           1.5          0.2  Setosa
# 4           5.0          3.6           1.4          0.2  Setosa

# %%
df.columns
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
df.describe()
# Out:
#        sepal.length  sepal.width  petal.length  petal.width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.dtypes
# Out:
# sepal.length    float64
# sepal.width     float64
# petal.length    float64
# petal.width     float64
# variety          object
# dtype: object

# %%
df.sample(5)   # displays rows randomly
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 136           6.3          3.4           5.6          2.4   Virginica
# 26            5.0          3.4           1.6          0.4      Setosa
# 22            4.6          3.6           1.0          0.2      Setosa
# 46            5.1          3.8           1.6          0.2      Setosa
# 88            5.6          3.0           4.1          1.3  Versicolor

# %%
df.shape    # rows and columns of the dataset
# Out:
# (150, 5)

# %%
sliced_data = print(df[10:16])
print(sliced_data)
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# 13           4.3          3.0           1.1          0.1  Setosa
# 14           5.8          4.0           1.2          0.2  Setosa
# 15           5.7          4.4           1.5          0.4  Setosa
# None

# %%
specific_data = df[['variety']]
print(specific_data)
# Out:
#        variety
# 0       Setosa
# 1       Setosa
# 2       Setosa
# 3       Setosa
# 4       Setosa
# ..         ...
# 145  Virginica
# 146  Virginica
# 147  Virginica
# 148  Virginica
# 149  Virginica
#
# [150 rows x 1 columns]

# %%
specific_data.head()
# Out:
#   variety
# 0  Setosa
# 1  Setosa
# 2  Setosa
# 3  Setosa
# 4  Setosa

# %%
df.iloc[5]
# Out:
# sepal.length       5.4
# sepal.width        3.9
# petal.length       1.7
# petal.width        0.4
# variety         Setosa
# Name: 5, dtype: object

# %%
df.loc[df['variety'] == 'Setosa']
# Out:
#     sepal.length  sepal.width  petal.length  petal.width variety
# 0            5.1          3.5           1.4          0.2  Setosa
# 1            4.9          3.0           1.4          0.2  Setosa
# 2            4.7          3.2           1.3          0.2  Setosa
# 3            4.6          3.1           1.5          0.2  Setosa
# 4            5.0          3.6           1.4          0.2  Setosa
# 5            5.4          3.9           1.7          0.4  Setosa
# 6            4.6          3.4           1.4          0.3  Setosa
# 7            5.0          3.4           1.5          0.2  Setosa
# 8            4.4          2.9           1.4          0.2  Setosa
# 9            4.9          3.1           1.5          0.1  Setosa
# 10           5.4          3.7           1.5          0.2  Setosa
# 11           4.8          3.4           1.6          0.2  Setosa
# 12           4.8          3.0           1.4          0.1  Setosa
# ...

# %%
df['variety'].value_counts()
# Out:
# variety
# Setosa        50
# Versicolor    50
# Virginica     50
# Name: count, dtype: int64

# %%
sum_data = df['sepal.length'].sum()
print("Sum data = ",sum_data)
mean_data = df['sepal.width'].mean()
print("Mean data = ",mean_data)
median_data = df['petal.length'].median()
print("Median data = ",median_data)
# Out:
# Sum data =  876.5
# Mean data =  3.0573333333333337
# Median data =  4.35

# %%
min_data = df['petal.width'].min()
print("Minimum =",min_data)
max_data = df['petal.width'].max()
print("Maximum =",max_data)
# Out:
# Minimum = 0.1
# Maximum = 2.5

# %%
cols = df.columns
print(cols)
# Out:
# Index(['sepal.length', 'sepal.width', 'petal.length', 'petal.width',
#        'variety'],
#       dtype='object')

# %%
cols = cols[1:5]
# columns with the integer values

# %%
df1 = df[cols]
# will save it from new dataframe variable

# %%
df["total_values"] = df1[cols].sum(axis=0) 
# add new column in the dataframe

# %%
df
# Out:
#      sepal.length  sepalwidth  petallength  petalwidth    variety total_values
# 0             5.1         3.5          1.4         0.2     Setosa          NaN
# 1             4.9         3.0          1.4         0.2     Setosa          NaN
# 2             4.7         3.2          1.3         0.2     Setosa          NaN
# 3             4.6         3.1          1.5         0.2     Setosa          NaN
# 4             5.0         3.6          1.4         0.2     Setosa          NaN
# ..            ...         ...          ...         ...        ...          ...
# 145           6.7         3.0          5.2         2.3  Virginica          NaN
# 146           6.3         2.5          5.0         1.9  Virginica          NaN
# 147           6.5         3.0          5.2         2.0  Virginica          NaN
# 148           6.2         3.4          5.4         2.3  Virginica          NaN
# 149           5.9         3.0          5.1         1.8  Virginica          NaN
#
# [150 rows x 6 columns]

# %%
newcols = {
    "sepal.length" : "sepallength",
    "sepal.width" : "sepalwidth",
    "petal.length" : "petallength",
    "petal.width" : "petalwidth"
}

df.rename(columns = newcols, inplace = True)

print(df.head())
# Out:
#    sepallength  sepalwidth  petallength  petalwidth variety total_values
# 0          5.1         3.5          1.4         0.2  Setosa          NaN
# 1          4.9         3.0          1.4         0.2  Setosa          NaN
# 2          4.7         3.2          1.3         0.2  Setosa          NaN
# 3          4.6         3.1          1.5         0.2  Setosa          NaN
# 4          5.0         3.6          1.4         0.2  Setosa          NaN

# %%
df.head(10).style.highlight_max(color='grey', axis=0)
# Out:
# <style type="text/css">
# #T_27925_row0_col4, #T_27925_row1_col4, #T_27925_row2_col4, #T_27925_row3_col4, #T_27925_row4_col4, #T_27925_row5_col0, #T_27925_row5_col1, #T_27925_row5_col2, #T_27925_row5_col3, #T_27925_row5_col4, #T_27925_row6_col4, #T_27925_row7_col4, #T_27925_row8_col4, #T_27925_row9_col4 {
#   background-color: grey;
# }
# </style>
# <table id="T_27925">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27925_level0_col0" class="col_heading level0 col0" >sepallength</th>
#       <th id="T_27925_level0_col1" class="col_heading level0 col1" >sepalwidth</th>
#       <th id="T_27925_level0_col2" class="col_heading level0 col2" >petallength</th>
#       <th id="T_27925_level0_col3" class="col_heading level0 col3" >petalwidth</th>
#       <th id="T_27925_level0_col4" class="col_heading level0 col4" >variety</th>
#       <th id="T_27925_level0_col5" class="col_heading level0 col5" >total_values</th>
#     </tr>
#   </thead>
#   <tbody>
# ...

# %%
df.isnull()
# Out:
#      sepallength  sepalwidth  petallength  petalwidth  variety  total_values
# 0          False       False        False       False    False          True
# 1          False       False        False       False    False          True
# 2          False       False        False       False    False          True
# 3          False       False        False       False    False          True
# 4          False       False        False       False    False          True
# ..           ...         ...          ...         ...      ...           ...
# 145        False       False        False       False    False          True
# 146        False       False        False       False    False          True
# 147        False       False        False       False    False          True
# 148        False       False        False       False    False          True
# 149        False       False        False       False    False          True
#
# [150 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Scatter plot of sepal length vs sepal width
sns.scatterplot(x='sepallength', y='sepalwidth', data=df, hue='variety')
plt.show()
